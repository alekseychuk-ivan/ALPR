# %%
# !pip install ultralytics
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.9/301.9 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 10.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ultralytics
from ultralytics import YOLO
import cv2 as cv
from google.colab.patches import cv2_imshow

# %% [markdown]
# download data from roboflow

# %%
# !curl -L "https://app.roboflow.com/ds/Yk7kinlje7?key=D1aw0kJPZ0" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: train/images/49694172338_7d1d027735_b_jpg.rf.f494e650b95b48047897608ae33daa24.jpg
#  extracting: train/images/49854179718_fac78c5147_b_jpg.rf.0ad32294db1756f788d42eb750c15aac.jpg
#  extracting: train/images/49854179718_fac78c5147_b_jpg.rf.49f5099b26acea4608ee9f6da70f9f19.jpg
#  extracting: train/images/49854179718_fac78c5147_b_jpg.rf.dd7160acea8458fb4e4a66f10c0655d2.jpg
#  extracting: train/images/4b3aba5dfb7a0492_jpg.rf.3a84b20fadfc54df9d5e63a104c50323.jpg
#  extracting: train/images/4b3aba5dfb7a0492_jpg.rf.8294dd451162aa261da5b3f6ed444524.jpg
#  extracting: train/images/4b3aba5dfb7a0492_jpg.rf.b30e71490847bd6dcc288818e348cd76.jpg
#  extracting: train/images/4c04b488ddc48225_jpg.rf.8a075ba1c3015ba187cd2d5422b39799.jpg
#  extracting: train/images/4c04b488ddc48225_jpg.rf.a727809445e2933d3e60a37e31883d5b.jpg
#  extracting: train/images/4c04b488ddc48225_jpg.rf.f4c3eae9d89cdbe7b4250c2e21aa7143.jpg
# ...

# %% [markdown]
# create model and run train

# %%
model = YOLO("yolov8n.pt")
model.train(data='data.yaml', epochs=50, batch=32) # epochs=50
# Out:
# Ultralytics YOLOv8.0.47 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# ...

# %% [markdown]
# run predict model, if need save image with detection flag save=True

# %%
model.predict(source='https://cdn2.hubspot.net/hub/120744/file-1188070748-jpg/images/know_what_plates_to_get_for_your_business_vehicle_with_commercial_insurance_from_andrew_gordon_inc.jpg', save=True)

# %%
outputs = model.predict(source='https://cdn2.hubspot.net/hub/120744/file-1188070748-jpg/images/know_what_plates_to_get_for_your_business_vehicle_with_commercial_insurance_from_andrew_gordon_inc.jpg')
